# %%
import pandas as pd

# %%
file = '../team_data/지역별 IT산업 매출액 통계.xlsx'
data = pd.read_excel(file, header = [0,1], index_col = [0,1,2])
data
# Out:
# ICT산업별(3)                                     2019                          \
# ICT산업별(3)                                       합계      서울       경기     인천
# 정보통신방송기기       소계         소계               3227288   50310  1528706  85869
#                전자부품       소계               1999287   11118  1209941  46731
#                           반도체              1123817    3837   868586  16305
#                           평판디스플레이           582041     509   197454   1498
#                           센서                 17025    2140     9136    932
#                           전자관                 1424       0      107    104
#                           수동부품               64351    2265    39271   2398
#                           PCB               123324     432    53390  20590
#                           접속부품               72682    1656    36499   4262
#                           기타전자부품             14622     280     5497    642
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 35 entries, ('정보통신방송기기', '소계', '소계') to ('소프트웨어 및 디지털콘텐츠', 'IT서비스', '기타IT서비스')
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   (2019, 합계)                  35 non-null     int64
#  1   (2019, 서울)                  35 non-null     int64
#  2   (2019, 경기)                  35 non-null     int64
#  3   (2019, 인천)                  35 non-null     int64
#  4   (2019, 부산, 울산, 경남)          35 non-null     int64
#  5   (2019, 대구, 경북)              35 non-null     int64
#  6   (2019, 광주, 전남, 전북, 제주)      35 non-null     int64
#  7   (2019, 대전, 충남, 충북, 세종, 강원)  35 non-null     int64
#  8   (2020, 합계)                  35 non-null     int64
#  9   (2020, 서울)                  35 non-null     int64
#  10  (2020, 경기)                  35 non-null     int64
#  11  (2020, 인천)                  35 non-null     int64
# ...

# %%
data.index
# Out:
# MultiIndex([(      '정보통신방송기기',         '소계',              '소계'),
#             (      '정보통신방송기기',       '전자부품',              '소계'),
#             (      '정보통신방송기기',       '전자부품',             '반도체'),
#             (      '정보통신방송기기',       '전자부품',         '평판디스플레이'),
#             (      '정보통신방송기기',       '전자부품',              '센서'),
#             (      '정보통신방송기기',       '전자부품',             '전자관'),
#             (      '정보통신방송기기',       '전자부품',            '수동부품'),
#             (      '정보통신방송기기',       '전자부품',             'PCB'),
#             (      '정보통신방송기기',       '전자부품',            '접속부품'),
#             (      '정보통신방송기기',       '전자부품',          '기타전자부품'),
#             (      '정보통신방송기기', '컴퓨터 및 주변기기',              '소계'),
#             (      '정보통신방송기기', '컴퓨터 및 주변기기',             '컴퓨터'),
#             (      '정보통신방송기기', '컴퓨터 및 주변기기',            '주변기기'),
#             (      '정보통신방송기기',  '통신 및 방송기기',              '소계'),
# ...

# %%
data1 = data.xs('전자부품', level = 1)
data1
# Out:
# ICT산업별(3)            2019                                            \
# ICT산업별(3)              합계     서울       경기     인천 부산, 울산, 경남  대구, 경북
# 정보통신방송기기 소계       1999287  11118  1209941  46731      35322  114100
#          반도체      1123817   3837   868586  16305       5008   37229
#          평판디스플레이   582041    509   197454   1498       1264   48572
#          센서         17025   2140     9136    932        935    1247
#          전자관         1424      0      107    104        643     391
#          수동부품       64351   2265    39271   2398       8166    4420
#          PCB       123324    432    53390  20590      10164    8928
#          접속부품       72682   1656    36499   4262       8593    8775
#          기타전자부품     14622    280     5497    642        550    4538
#
# ICT산업별(3)                                              2020         ...  \
# ICT산업별(3)        광주, 전남, 전북, 제주 대전, 충남, 충북, 세종, 강원       합계     서울  ...
# 정보통신방송기기 소계               32166             549908  2043782  14234  ...
# ...

# %%
data1.columns
# Out:
# MultiIndex([('2019',                 '합계'),
#             ('2019',                 '서울'),
#             ('2019',                 '경기'),
#             ('2019',                 '인천'),
#             ('2019',         '부산, 울산, 경남'),
#             ('2019',             '대구, 경북'),
#             ('2019',     '광주, 전남, 전북, 제주'),
#             ('2019', '대전, 충남, 충북, 세종, 강원'),
#             ('2020',                 '합계'),
#             ('2020',                 '서울'),
#             ('2020',                 '경기'),
#             ('2020',                 '인천'),
#             ('2020',         '부산, 울산, 경남'),
#             ('2020',             '대구, 경북'),
#             ('2020',     '광주, 전남, 전북, 제주'),
#             ('2020', '대전, 충남, 충북, 세종, 강원'),
#             ('2021',                 '합계'),
#             ('2021',                 '서울'),
#             ('2021',                 '경기'),
#             ('2021',                 '인천'),
#             ('2021',         '부산, 울산, 경남'),
# ...
