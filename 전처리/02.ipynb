# %%
import pandas as pd

# %%
file = '../team_data/경영애로사항_20240129202845.xlsx'

# %%
#data = pd.read_excel(file)
#data

# %%
data = pd.read_excel(file, header = [0,1] , index_col =[0,1])
data
# Out:
# C:\ProgramData\anaconda3\envs\My_38\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 특성별(2)                    2019                                          \
# 특성별(2)              모집단 크기 (개) 자금 확보 (%) 필요인력 확보 (%) 판매부진 (%) 과다경쟁 (%)
# 업종별     소프트웨어            19670      35.2        38.6     23.4     21.4
# 세부 업종별  전자부품             10144      45.6        30.4     29.4     28.5
#         컴퓨터 및 주변기기        1012      38.9        31.2     27.2     17.3
#         통신 및 방송기기         2736      34.9        30.9     26.3     28.8
#         영상 및 음향기기          935      32.9        17.5     34.0     31.8
#         정보통신응용기반기기       19594      36.2        24.0     37.2     21.2
#         패키지 소프트웨어        11441      34.8        38.7     20.1     16.5
#         게임소프트웨어           1619      37.1        50.7     21.7     18.0
# ...

# %%
#data.T

# %%
data_area = data.xs('권역별', level = 0)
data_area
# Out:
# 특성별(2)            2019                                                      \
# 특성별(2)      모집단 크기 (개) 자금 확보 (%) 필요인력 확보 (%) 판매부진 (%) 과다경쟁 (%) 소비심리 위축 (%)
# 서울               19504      34.0        32.2     26.6     18.1        23.8
# 인천/경기            21847      38.4        29.6     29.6     23.2        16.2
# 대전/세종/충청/강원       4450      44.7        39.0     25.8     33.1         6.1
# 부산/울산/경남          6278      34.3        23.5     43.7     33.2        39.0
# 대구/경북             3823      45.7        34.6     35.8     20.0        22.9
# 광주/전라/제주          2413      13.3        34.5      8.1     28.3         3.5
#
# 특성별(2)                                                        ...        2021  \
# 특성별(2)      임금 상승 (%) 수익성 악화 (%) 판로 확보 (%) 기술혁신/신제품 개발부진 (%)  ... 수주조건 악화 (%)
# 서울               11.3       11.9      14.6              11.9  ...         5.0
# 인천/경기            23.8       24.7      21.2              18.7  ...        17.5
# ...

# %%
data_area.xs('2019',level = 0, axis = 1)
# Out:
# 특성별(2)       모집단 크기 (개)  자금 확보 (%)  필요인력 확보 (%)  판매부진 (%)  과다경쟁 (%)  \
# 서울                19504       34.0         32.2      26.6      18.1
# 인천/경기             21847       38.4         29.6      29.6      23.2
# 대전/세종/충청/강원        4450       44.7         39.0      25.8      33.1
# 부산/울산/경남           6278       34.3         23.5      43.7      33.2
# 대구/경북              3823       45.7         34.6      35.8      20.0
# 광주/전라/제주           2413       13.3         34.5       8.1      28.3
#
# 특성별(2)       소비심리 위축 (%)  임금 상승 (%)  수익성 악화 (%)  판로 확보 (%)  기술혁신/신제품 개발부진 (%)  \
# 서울                  23.8       11.3        11.9       14.6               11.9
# 인천/경기               16.2       23.8        24.7       21.2               18.7
# 대전/세종/충청/강원          6.1       21.1        18.6        5.6               33.4
# 부산/울산/경남            39.0       16.8         8.5        6.2               13.4
# 대구/경북               22.9       18.3        17.1       45.8                7.6
# ...

# %%
data_area.xs('2020',level = 0, axis = 1)
# Out:
# 특성별(2)       모집단 크기 (개)  자금 확보 (%)  필요인력 확보 (%)  판매부진 (%)  과다경쟁 (%)  \
# 서울                18376       29.1         23.0      48.2      28.5
# 인천/경기             23540       34.0         18.8      52.7      54.3
# 대전/세종/충청/강원        5754       31.2         26.9      29.7      31.1
# 부산/울산/경남           5317       30.9         25.8      37.2      37.1
# 대구/경북              3697       36.4         19.5      44.5      30.3
# 광주/전라/제주           3196       27.0         21.0      42.2      33.1
#
# 특성별(2)       소비심리 위축 (%)  임금 상승 (%)  수익성 악화 (%)  판로 확보 (%)  기술혁신/신제품 개발부진 (%)  \
# 서울                  34.1       17.5        10.3       11.2               20.3
# 인천/경기               21.5       17.1        40.6       46.5               42.5
# 대전/세종/충청/강원         20.4       14.8         8.2       10.0               18.4
# 부산/울산/경남            21.3       26.3         9.4       14.8               27.5
# 대구/경북               28.2        9.9        15.0       16.8               17.4
# ...

# %%
data_area.xs('2021',level = 0, axis = 1)
# Out:
# 특성별(2)       모집단 크기 (개)  자금 확보 (%)  필요인력 확보 (%)  판매부진 (%)  과다경쟁 (%)  \
# 서울                18376       29.1         23.0      48.2      28.5
# 인천/경기             23540       34.0         18.8      52.7      54.3
# 대전/세종/충청/강원        5754       31.2         26.9      29.7      31.1
# 부산/울산/경남           5317       30.9         25.8      37.2      37.1
# 대구/경북              3697       36.4         19.5      44.5      30.3
# 광주/전라/제주           3196       27.0         21.0      42.2      33.1
#
# 특성별(2)       소비심리 위축 (%)  임금 상승 (%)  수익성 악화 (%)  판로 확보 (%)  기술혁신/신제품 개발부진 (%)  \
# 서울                  34.1       17.5        10.3       11.2               20.3
# 인천/경기               21.5       17.1        40.6       46.5               42.5
# 대전/세종/충청/강원         20.4       14.8         8.2       10.0               18.4
# 부산/울산/경남            21.3       26.3         9.4       14.8               27.5
# 대구/경북               28.2        9.9        15.0       16.8               17.4
# ...
