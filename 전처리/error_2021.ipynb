# %%
import pandas as pd
import matplotlib.pyplot as plt
import platform
import koreanize_matplotlib

# %%
file = '../team_data/경영애로사항_2021.xlsx'
data = pd.read_excel(file, index_col = [0,1], header = [0], skiprows=1)
data
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                      모집단 크기 (개)  자금 확보 (%)  필요인력 확보 (%)  판매부진 (%)  \
# 특성별(1)  특성별(2)
# 전체      소계                59998       42.4         31.8      17.8
# 업종별     정보통신방송서비스          4294       31.3         35.1      19.9
#         정보통신방송기기          34662       43.7         27.8      21.1
#         소프트웨어             21042       42.4         37.6      12.0
# 세부 업종별  통신서비스               400       33.5         33.5      19.2
#         방송서비스              1193       33.7         36.9      21.4
#         정보서비스              2701       29.9         34.6      19.4
#         전자부품              10211       45.6         28.8      16.6
#         컴퓨터 및 주변기기         1049       35.0         39.2      26.4
#         통신 및 방송기기          2684       47.6         46.5      14.7
#         영상 및 음향기기           921       39.1         25.9      17.5
#         정보통신응용기반기기        19797       42.9         24.3      24.2
#         패키지 소프트웨어         12635       45.7         42.6      10.7
#         게임소프트웨어            1648       27.2         29.6      33.3
#         IT서비스              6759       39.8         30.2       9.3
# 매출액 규모별 1억 미만             15402       49.3         24.3      22.4
#         1억~5억 미만          19500       40.4         26.2      17.4
#         5억~10억 미만          7803       45.7         36.7      14.1
#         10억~50억 미만        12241       41.5         41.3      18.3
#         50억~100억 미만        2550       30.7         45.4       7.8
#         100억 이상            2502       20.4         46.3      12.9
# 종사자 규모별 1~9명              42169       43.6         27.8      20.5
#         10~19명             8317       49.2         38.4      11.8
#         20~49명             6599       33.6         45.1      11.1
#         50~99명             2074       25.1         36.8      11.2
#         100~299명            775       24.3         51.0      11.6
#         300명 이상              64       13.2         71.0       6.9
# 권역별     서울                19676       36.4         32.1      20.1
#         인천/경기             20760       46.5         34.1      14.7
#         대전/세종/충청/강원        7635       41.5         37.1      16.0
#         부산/울산/경남           7613       48.0         22.8      28.9
#         대구/경북              2502       31.9         18.2       5.8
#         광주/전라/제주           1812       53.5         36.6       7.1
#
#                      업계내 과당경쟁 (%)  판로 확보 (%)  신기술·신제품 개발 (%)  마케팅 (%)  \
# 특성별(1)  특성별(2)
# 전체      소계                   24.9       29.0            23.0     13.2
# 업종별     정보통신방송서비스            32.4       27.7            10.3     19.7
#         정보통신방송기기             25.5       27.4            22.5     12.0
#         소프트웨어                22.3       32.1            26.5     13.9
# 세부 업종별  통신서비스                27.9       31.1             3.7      8.2
#         방송서비스                36.9       27.1            13.6     21.9
#         정보서비스                31.1       27.5             9.8     20.4
#         전자부품                 24.1       27.4            22.2      8.2
#         컴퓨터 및 주변기기           19.0       25.5            23.7     13.4
#         통신 및 방송기기            26.6       15.8            38.5     13.4
#         영상 및 음향기기            25.4       24.9            24.9      9.2
#         정보통신응용기반기기           26.4       29.1            20.3     13.8
#         패키지 소프트웨어            23.0       35.6            24.3     11.2
#         게임소프트웨어              25.0       28.4            32.0     11.2
#         IT서비스                20.5       26.4            29.2     19.4
# 매출액 규모별 1억 미만                24.2       32.1            20.1     18.6
#         1억~5억 미만             25.3       35.3            17.6     11.0
#         5억~10억 미만            21.6       26.9            21.3     10.0
#         10억~50억 미만           26.3       19.9            36.2     12.3
#         50억~100억 미만          25.7       21.7            27.3     14.1
#         100억 이상              28.4       20.7            19.3     11.2
# 종사자 규모별 1~9명                 26.0       31.0            19.5     13.7
#         10~19명               21.5       27.1            32.7      8.4
#         20~49명               20.6       22.5            31.6     16.0
#         50~99명               28.8       21.9            31.4     13.7
#         100~299명             28.1       21.3            19.0     11.4
#         300명 이상              25.3       15.9             5.5      9.8
# 권역별     서울                   21.7       36.3            12.9     12.5
#         인천/경기                24.0       25.7            32.1     12.9
#         대전/세종/충청/강원          34.7       14.7            16.9     16.3
#         부산/울산/경남             26.9       18.8            32.8     11.0
#         대구/경북                29.0       63.9             9.3     22.6
#         광주/전라/제주             13.4       44.7            31.5      7.3
#
#                      수주조건 악화 (%)  원자재 수급 곤란 및 가격 상승 (%)  각종 규제 (%)  \
# 특성별(1)  특성별(2)
# 전체      소계                  11.3                   16.9        7.9
# 업종별     정보통신방송서비스            7.2                    8.2        6.2
#         정보통신방송기기            13.8                   22.7        8.8
#         소프트웨어                7.9                    9.1        6.7
# 세부 업종별  통신서비스                4.5                   14.9        3.6
#         방송서비스                9.1                   14.7        5.9
#         정보서비스                6.8                    4.4        6.7
#         전자부품                15.0                   20.7        7.9
#         컴퓨터 및 주변기기          13.3                   21.3        7.7
#         통신 및 방송기기           25.8                   37.3       13.1
#         영상 및 음향기기           17.3                   23.2       13.9
#         정보통신응용기반기기          11.5                   21.7        8.6
#         패키지 소프트웨어            8.8                    8.6        7.4
#         게임소프트웨어              4.2                   10.6        6.4
#         IT서비스                7.2                    9.6        5.5
# 매출액 규모별 1억 미만               11.2                   15.4        5.2
#         1억~5억 미만            11.4                   12.0        8.1
#         5억~10억 미만            8.3                   18.1        8.8
#         10억~50억 미만          13.2                   21.8        8.9
#         50억~100억 미만         10.3                   27.5       12.2
#         100억 이상             11.6                   25.6       11.0
# 종사자 규모별 1~9명                11.2                   15.5        7.3
#         10~19명              13.2                   21.0        6.9
#         20~49명              10.1                   20.5       11.8
#         50~99명               9.8                   16.6       11.9
#         100~299명             7.5                   19.1        7.4
#         300명 이상              6.6                   17.7        1.6
# 권역별     서울                   5.0                    9.2        4.6
#         인천/경기               17.5                   23.8        9.7
#         대전/세종/충청/강원         10.5                   23.8        8.3
#         부산/울산/경남            15.4                    3.3        1.9
#         대구/경북                4.0                   34.3       33.3
#         광주/전라/제주             4.1                   24.3       11.9
#
#                      대기업과의 협력관계 (%) 환율 변동 (%)  금리변동 (%) 조직관리 (%) 정보/기술 유출 (%)  \
# 특성별(1)  특성별(2)
# 전체      소계                      3.6       7.9      12.7      1.3            2
# 업종별     정보통신방송서비스               2.4       1.8       4.2      1.2          1.7
#         정보통신방송기기                3.8      10.5      16.4      1.6          1.5
#         소프트웨어                   3.4       4.9       8.4      0.8          2.8
# 세부 업종별  통신서비스                   4.1         -       6.3        -            -
#         방송서비스                   4.9       0.3       2.6      0.4          2.1
#         정보서비스                   1.1       2.8       4.6      1.8          1.8
#         전자부품                    1.6      10.1      20.3        3          1.6
#         컴퓨터 및 주변기기              5.5      18.9      17.9      0.9          1.2
#         통신 및 방송기기               3.2      18.7      31.6      0.6          5.2
#         영상 및 음향기기               3.3      14.3      16.8      0.1          1.3
#         정보통신응용기반기기              5.0       8.9      12.2      1.2            1
#         패키지 소프트웨어               3.0       6.6       9.2      0.7          3.3
#         게임소프트웨어                 3.4       2.1       2.5      0.6            3
#         IT서비스                   4.0       2.4       8.3      1.2          1.8
# 매출액 규모별 1억 미만                   1.8       6.7       8.1      0.4          1.1
#         1억~5억 미만                2.5         5      10.5      1.2          1.2
#         5억~10억 미만               2.1       6.2      11.6        -          2.4
#         10억~50억 미만              6.3      12.2      21.1      2.7          3.3
#         50억~100억 미만             9.2      13.1      17.4      4.8          4.8
#         100억 이상                 8.3      16.3      15.7      1.6            3
# 종사자 규모별 1~9명                    2.6         7      11.9      0.9          1.7
#         10~19명                  4.4       9.5      14.6      2.4          2.5
#         20~49명                  5.8      10.1      15.5      2.3          2.4
#         50~99명                 11.1       9.7      12.8      1.2          4.6
#         100~299명                8.1      13.6      12.4      0.5          3.2
#         300명 이상                13.7       7.2       8.4      6.8          1.6
# 권역별     서울                      2.6       3.3       4.1      0.2          0.9
#         인천/경기                   3.3      14.2      25.6      3.2          3.6
#         대전/세종/충청/강원             1.2       7.8       9.0      0.4          1.4
#         부산/울산/경남                1.1       1.7       5.0      0.5            -
#         대구/경북                  20.5       9.1      13.4        -          4.6
#         광주/전라/제주               14.3      10.3       4.6      1.7          2.6
#
#                     관련기업 부도/도산 (%) 기타 (%)
# 특성별(1)  특성별(2)
# 전체      소계                     1.9    1.5
# 업종별     정보통신방송서비스              1.6      3
#         정보통신방송기기               2.7    0.8
#         소프트웨어                  0.5    2.2
# 세부 업종별  통신서비스                  0.8    1.6
#         방송서비스                  3.1    2.4
#         정보서비스                  1.1    3.5
#         전자부품                   1.8    2.1
#         컴퓨터 및 주변기기             2.5    0.8
#         통신 및 방송기기              1.2    2.3
#         영상 및 음향기기              0.8    0.9
#         정보통신응용기반기기             3.5      -
#         패키지 소프트웨어              0.2    1.8
#         게임소프트웨어                0.9    0.4
#         IT서비스                    1    3.4
# 매출액 규모별 1억 미만                  3.3    4.9
#         1억~5억 미만               0.9    0.3
#         5억~10억 미만              0.3      -
#         10억~50억 미만             2.4    0.3
#         50억~100억 미만            3.4    0.2
#         100억 이상                2.1    0.8
# 종사자 규모별 1~9명                   2.1    1.5
#         10~19명                 1.6      2
#         20~49명                 1.6    1.2
#         50~99명                 1.2    0.1
#         100~299명                 -      1
#         300명 이상                  -    3.7
# 권역별     서울                     0.2    1.9
#         인천/경기                  4.1    2.1
#         대전/세종/충청/강원            2.7      -
#         부산/울산/경남                 -    0.4
#         대구/경북                    -    1.3
#         광주/전라/제주               1.6    0.3

# %%
d = data.xs('권역별', level = 0)
d
# Out:
#              모집단 크기 (개)  자금 확보 (%)  필요인력 확보 (%)  판매부진 (%)  업계내 과당경쟁 (%)  \
# 특성별(2)
# 서울                19676       36.4         32.1      20.1          21.7
# 인천/경기             20760       46.5         34.1      14.7          24.0
# 대전/세종/충청/강원        7635       41.5         37.1      16.0          34.7
# 부산/울산/경남           7613       48.0         22.8      28.9          26.9
# 대구/경북              2502       31.9         18.2       5.8          29.0
# 광주/전라/제주           1812       53.5         36.6       7.1          13.4
#
#              판로 확보 (%)  신기술·신제품 개발 (%)  마케팅 (%)  수주조건 악화 (%)  \
# 특성별(2)
# 서울                36.3            12.9     12.5          5.0
# 인천/경기             25.7            32.1     12.9         17.5
# 대전/세종/충청/강원       14.7            16.9     16.3         10.5
# 부산/울산/경남          18.8            32.8     11.0         15.4
# 대구/경북             63.9             9.3     22.6          4.0
# 광주/전라/제주          44.7            31.5      7.3          4.1
#
#              원자재 수급 곤란 및 가격 상승 (%)  각종 규제 (%)  대기업과의 협력관계 (%) 환율 변동 (%)  \
# 특성별(2)
# 서울                             9.2        4.6             2.6       3.3
# 인천/경기                         23.8        9.7             3.3      14.2
# 대전/세종/충청/강원                   23.8        8.3             1.2       7.8
# 부산/울산/경남                       3.3        1.9             1.1       1.7
# 대구/경북                         34.3       33.3            20.5       9.1
# 광주/전라/제주                      24.3       11.9            14.3      10.3
#
#              금리변동 (%) 조직관리 (%) 정보/기술 유출 (%) 관련기업 부도/도산 (%) 기타 (%)
# 특성별(2)
# 서울                4.1      0.2          0.9            0.2    1.9
# 인천/경기            25.6      3.2          3.6            4.1    2.1
# 대전/세종/충청/강원       9.0      0.4          1.4            2.7      -
# 부산/울산/경남          5.0      0.5            -              -    0.4
# 대구/경북            13.4        -          4.6              -    1.3
# 광주/전라/제주          4.6      1.7          2.6            1.6    0.3

# %%
d = d.T
d = d.drop(['모집단 크기 (개)'], axis = 0)
d = d.head(20)
d = d.replace('-',0)

# %%
d
# Out:
# 특성별(2)                   서울  인천/경기  대전/세종/충청/강원  부산/울산/경남  대구/경북  광주/전라/제주
# 자금 확보 (%)              36.4   46.5         41.5      48.0   31.9      53.5
# 필요인력 확보 (%)            32.1   34.1         37.1      22.8   18.2      36.6
# 판매부진 (%)               20.1   14.7         16.0      28.9    5.8       7.1
# 업계내 과당경쟁 (%)           21.7   24.0         34.7      26.9   29.0      13.4
# 판로 확보 (%)              36.3   25.7         14.7      18.8   63.9      44.7
# 신기술·신제품 개발 (%)         12.9   32.1         16.9      32.8    9.3      31.5
# 마케팅 (%)                12.5   12.9         16.3      11.0   22.6       7.3
# 수주조건 악화 (%)             5.0   17.5         10.5      15.4    4.0       4.1
# 원자재 수급 곤란 및 가격 상승 (%)   9.2   23.8         23.8       3.3   34.3      24.3
# 각종 규제 (%)               4.6    9.7          8.3       1.9   33.3      11.9
# 대기업과의 협력관계 (%)          2.6    3.3          1.2       1.1   20.5      14.3
# 환율 변동 (%)               3.3   14.2          7.8       1.7    9.1      10.3
# 금리변동 (%)                4.1   25.6          9.0       5.0   13.4       4.6
# 조직관리 (%)                0.2    3.2          0.4       0.5    0.0       1.7
# 정보/기술 유출 (%)            0.9    3.6          1.4       0.0    4.6       2.6
# 관련기업 부도/도산 (%)          0.2    4.1          2.7       0.0    0.0       1.6
# 기타 (%)                  1.9    2.1          0.0       0.4    1.3       0.3

# %%
d.columns
# Out:
# Index(['서울', '인천/경기', '대전/세종/충청/강원', '부산/울산/경남', '대구/경북', '광주/전라/제주'], dtype='object', name='특성별(2)')

# %%
xlist = list(d.columns)
ylist = list(d.index)
xlist
# Out:
# ['서울', '인천/경기', '대전/세종/충청/강원', '부산/울산/경남', '대구/경북', '광주/전라/제주']

# %%
ylist
# Out:
# ['자금 확보 (%)',
#  '필요인력 확보 (%)',
#  '판매부진 (%)',
#  '업계내 과당경쟁 (%)',
#  '판로 확보 (%)',
#  '신기술·신제품 개발 (%)',
#  '마케팅 (%)',
#  '수주조건 악화 (%)',
#  '원자재 수급 곤란 및 가격 상승 (%)',
#  '각종 규제 (%)',
#  '대기업과의 협력관계 (%)',
#  '환율 변동 (%)',
#  '금리변동 (%)',
#  '조직관리 (%)',
#  '정보/기술 유출 (%)',
#  '관련기업 부도/도산 (%)',
#  '기타 (%)']

# %%
data = d['서울']
data
# Out:
# 자금 확보 (%)                36.4
# 필요인력 확보 (%)              32.1
# 판매부진 (%)                 20.1
# 업계내 과당경쟁 (%)             21.7
# 판로 확보 (%)                36.3
# 신기술·신제품 개발 (%)           12.9
# 마케팅 (%)                  12.5
# 수주조건 악화 (%)               5.0
# 원자재 수급 곤란 및 가격 상승 (%)     9.2
# 각종 규제 (%)                 4.6
# 대기업과의 협력관계 (%)            2.6
# 환율 변동 (%)                 3.3
# 금리변동 (%)                  4.1
# 조직관리 (%)                  0.2
# 정보/기술 유출 (%)              0.9
# 관련기업 부도/도산 (%)            0.2
# 기타 (%)                    1.9
# Name: 서울, dtype: float64

# %%
x = d.index
x
# Out:
# Index(['자금 확보 (%)', '필요인력 확보 (%)', '판매부진 (%)', '업계내 과당경쟁 (%)', '판로 확보 (%)',
#        '신기술·신제품 개발 (%)', '마케팅 (%)', '수주조건 악화 (%)', '원자재 수급 곤란 및 가격 상승 (%)',
#        '각종 규제 (%)', '대기업과의 협력관계 (%)', '환율 변동 (%)', '금리변동 (%)', '조직관리 (%)',
#        '정보/기술 유출 (%)', '관련기업 부도/도산 (%)', '기타 (%)'],
#       dtype='object')

# %%
y = d.values
y
# Out:
# array([[36.4, 46.5, 41.5, 48. , 31.9, 53.5],
#        [32.1, 34.1, 37.1, 22.8, 18.2, 36.6],
#        [20.1, 14.7, 16. , 28.9,  5.8,  7.1],
#        [21.7, 24. , 34.7, 26.9, 29. , 13.4],
#        [36.3, 25.7, 14.7, 18.8, 63.9, 44.7],
#        [12.9, 32.1, 16.9, 32.8,  9.3, 31.5],
#        [12.5, 12.9, 16.3, 11. , 22.6,  7.3],
#        [ 5. , 17.5, 10.5, 15.4,  4. ,  4.1],
#        [ 9.2, 23.8, 23.8,  3.3, 34.3, 24.3],
#        [ 4.6,  9.7,  8.3,  1.9, 33.3, 11.9],
#        [ 2.6,  3.3,  1.2,  1.1, 20.5, 14.3],
#        [ 3.3, 14.2,  7.8,  1.7,  9.1, 10.3],
#        [ 4.1, 25.6,  9. ,  5. , 13.4,  4.6],
#        [ 0.2,  3.2,  0.4,  0.5,  0. ,  1.7],
#        [ 0.9,  3.6,  1.4,  0. ,  4.6,  2.6],
#        [ 0.2,  4.1,  2.7,  0. ,  0. ,  1.6],
#        [ 1.9,  2.1,  0. ,  0.4,  1.3,  0.3]])

# %%
plt.figure(figsize = (20,10))
data.plot(kind = 'bar', grid = True, rot = 30)
plt.ylim(0, 60)
plt.title('[ 서울 ]', fontsize = 'xx-large')
plt.show()

# %%
def graph(city, c):
    data = d[city]
    x = d.index
    y = d.values
    plt.figure(figsize = (20,10))
    data.plot(kind = 'bar', grid = True, rot = 30, color = c)
    plt.ylim(0, 60)
    plt.title(city, fontsize = 'xx-large')
    plt.show()

# %%
graph('서울', 'blue')

# %%
graph('인천/경기', 'blue')

# %%
graph('대전/세종/충청/강원', 'blue')

# %%
graph('부산/울산/경남', 'blue')

# %%
graph('대구/경북', 'blue')

# %%
graph('광주/전라/제주', 'blue')

# %% [markdown]
# # 필요없는 그래프

# %%
def graph3_ad(data_name, x):
    # 전체 크기 설정
    plt.figure(figsize=(15,10))
    # 각 데이터 프레임 별로 시각화를 함
    graph = data_name.plot(kind = 'bar', grid = True, xlabel = x , ylabel ='평균점수', rot = 0,
                           fontsize = 'x-large', width = 0.2)
    graph = plt.ylim(0.0, 1.0)
    graph = plt.xlabel(x, loc = 'right', fontsize = 'xx-large')
    graph = plt.ylabel('평균점수', loc = 'top', fontsize = 'xx-large')
    graph = plt.title('[성인 - 피해 경험 후 심리 상태]', fontsize = 'xx-large')
    graph = plt.legend(['0~3점을 부여한 후 평균값 계산'], fontsize = 'xx-large')

# %%
graph_new('orange')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 graph_new('orange')
#
# Cell In[41], line 5, in graph_new(c)
#       2 plt.figure(figsize = (20,10))
#       4 for num in range(d.shape[1]):
# ----> 5     plt.bar(xlist, d.iloc[ylist[num]], color = c)
#       6     plt.ylim(0, 70)
#       7     plt.title(ylist[num])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1653, in _iLocIndexer._getitem_axis(self, key, axis)
#    1651 key = item_from_zerodim(key)
#    1652 if not is_integer(key):
# -> 1653     raise TypeError("Cannot index by location index with a non-integer key")
#    1655 # validate the location
#    1656 self._validate_integer(key, axis)
#
# TypeError: Cannot index by location index with a non-integer key

# %%
def graph (start, end, c):
    plt.figure(figsize = (20,10))
    
    for num in range(start, end+1):
        num1 = num - start + 1
        plt.subplot(1, 5, num1)
        plt.bar(xlist, d[ylist[num]], color = c)
        plt.ylim(0, 50)
        plt.title(xlist[num])
        #xticks를 rotation하고 싶은데 그건 어떻게 하는 거지?
        
plt.show()

# %%
graph(1,5,'green')

# %%
graph(6,10,'green')

# %%
graph(11,15,'green')

# %%
#필요없으므로 제거
#graph(16,17,'green')
